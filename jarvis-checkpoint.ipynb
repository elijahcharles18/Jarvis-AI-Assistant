# %%
pip install pyttsx3
# Out:
# ...
#   Using cached pyttsx3-2.98-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached comtypes-1.4.8-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# ...
# Using cached pyttsx3-2.98-py3-none-any.whl (34 kB)
# Using cached comtypes-1.4.8-py3-none-any.whl (229 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyttsx3 #pip install pyttsx3

# %%
engine = pyttsx3.init()

# %%
engine.say("hello world, this is jarvis!")
engine.runAndWait()

# %%
def speak(audio):
    engine.say(audio)
    engine.runAndWait()

speak("this is jarvis ai assistant")

# %%
import datetime # making jarvis to speak out time
def time():
    Time = datetime.datetime.now().strftime("%I:%M:%S")
    speak("the current time is")
    speak(Time)

# %%
# making jarvis to speak out the current date
def date():
    year = int(datetime.datetime.now().year)
    month = int(datetime.datetime.now().month)
    date = int(datetime.datetime.now().day)
    speak("the current date is")
    speak(date)
    speak(month)
    speak(year)

# %%
# Greetings functions
def wishme():
    speak("Welcome back sir!")
    speak("the current time is")
    time()
    speak("the current date is")
    date()
    hour = datetime.datetime.now().hour
    if hour >= 6 and hour<12:
        speak("Good morning sir!")
    elif hour >=12 and hour<18:
            speak("Good afternoon sir!")
    elif hour >=18 and hour<24:
            speak("Good evening sir!")
    else:
            speak("Good night sir!")
    speak("jarvis at your service please tell me how can i help you? ")

# %%
pip install SpeechRecognition
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade psutil
# Out:
# ...
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.0
#     Uninstalling psutil-5.9.0:
#       Successfully uninstalled psutil-5.9.0
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\USER\anaconda3\Lib\site-packages\~sutil'.
#   You can safely remove it manually.

# %%
pip install pyaudio

# %%
pip install pyautogui
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install  wikipedia
# Out:
# ...
#   Using cached wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11705 sha256=d205fe33bce27d0637222ba23138842bf8f06a26333c4f943d296755312c0903
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\63\47\7c\a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
# Successfully built wikipedia
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install psutil
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyjokes
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wikipedia
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr # pip install SpeechRecognition
import pyaudio
import wikipedia # pip install wikipedia
import webbrowser as wb
import os
import pyautogui # pip install pyautogui
import psutil # pip install --upgrade psutil
import pyjokes # pip install pyjokes

# %%
# Take command function
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)
    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(query)
        return query
    except Exception as e:
        print(e)
        speak("Say that again please...")
        return "None"
    
    
def sendEmail(to, contet):
        server = smtplib.SMTP('smtp.gmail.com', 587)
        server.ehlo()
        server.starttls()
        server.login('elijahcharlesenyi@gmail.com', 'William$300')
        server.sendmail('elijahcharlesenyi@gmail.com', to, content)
        server.close()
        
def screenshot():
    img = pyautogui.screenshot()
    img.save("C:\\Users\\USER\\Documents\\project\\jarvis\\ss.png")

def cpu():
    usage = str(psutil.cpu_percent())
    speak('CPU is at' + usage)
    battery = psutil.sensors_battery()
    speak("Battery is at")
    speak(battery.percent)
        
def jokes():
    speak(pyjokes.get_joke())
        
# Main function
if __name__ =="__main__":
    wishme()
    while True:
        query = takeCommand().lower()
        
        if 'time' in query:
            time()
        elif 'date' in query:
            date()
        elif 'wikipedia' in query:
            speak("Searching...")
            query = query.replace("wikipedia", "")
            result = wiikipedia.summary(query, sentences=2)
            print(result)
            speak(result)
        elif 'send email' in query:
            try:
                speak("What should I say")
                content = takeCommand()
                to = 'elijahcharlesenyi@gmail.com'
                # sendEmail(to, content)
                
                speak(content)
            except Exception as e:
                print(e)
                speak("Unable to send the email")
        elif 'search in chrome' in query:
            speak("What should i search?")
            chromepath = 'C:/Program Files (x86)/Google/Chrome/Application/chrome.exe %s'
            search = takeCommand().lower()
            wb.get(chromepath).open_new_tab(search+'.com')
            
        elif 'logout' in query:
            os.system("shutdown -l")
            
        elif 'shutdown' in query:
            os.system("shutdown /s /t 1")
            
        elif 'restart' in query:
            os.system("shutdown /r /t 1")
        
        elif 'play songs' in query:
            songs_dir = 'D:\\Music'
            songs = os.listdir(songs_dir)
            os.startfile(os.path.join(songs_dir, songs[0]))
            
        elif 'remember that' in query:
            speak("What should i remember?")
            data = takeCommand()
            speak("you said me to remember that"+data)
            remember = open('data.txt', 'w')
            remember.write(data)
            remember.close()    
        elif 'do you know anything' in query:
            remember = open('data.txt', 'r')
            speak("you said me to remember that" +remember.read())
            
        elif 'screenshot' in query:
            screenshot()
            speak("Done!")
            
            
        elif 'cpu' in query:
            cpu()
            
        elif 'joke' in query:
            jokes()

            
        elif 'offline' in query:
            quit()
# Out:
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\Lib\site-packages\comtypes\client\_events.py", line 125, in error_printer
#     return func(*args, **kw)
#            ^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\Lib\site-packages\pyttsx3\drivers\sapi5.py", line 182, in _ISpeechVoiceEvents_Word
#     current_word = current_text[char:char + length]
#                    ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# TypeError: 'int' object is not subscriptable
# Traceback (most recent call last):
#   File "C:\Users\USER\anaconda3\Lib\site-packages\comtypes\client\_events.py", line 125, in error_printer
#     return func(*args, **kw)
#            ^^^^^^^^^^^^^^^^^
#   File "C:\Users\USER\anaconda3\Lib\site-packages\pyttsx3\drivers\sapi5.py", line 182, in _ISpeechVoiceEvents_Word
#     current_word = current_text[char:char + length]
#                    ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# TypeError: 'int' object is not subscriptable
# Traceback (most recent call last):
# ...

# %%
pip install wikipedia

# %%
import wikipedia # pip install wikipedia

# %%
pip install --upgrade psutil
